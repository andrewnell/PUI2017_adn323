# %% [markdown]
# # SQL CARTO QUERY FUNCTION
# # written for PUI2016_Python2

# %% [markdown]
# ##### This notebook is set up to link as a default to the fb55 account.  To turn in the homework use the same account you used in the lab (hvt201)  and query the database that you were querying in class (citibike_feb_2015)

# %%
# SQL_SOURCE = 'https://fb55.carto.com/api/v2/sql?q='
SQL_SOURCE = 'https://andrewnell.carto.com/api/v2/sql?q='

import urllib2
import urllib
import StringIO
import ast
import pandas as pd

def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (andrewnell Carto account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urllib.urlencode({'format': format, 'q': query})
    try:
        response = urllib2.urlopen(source, data)
    except urllib2.HTTPError, e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

# %% [markdown]
# # TASK 1

# %%
# Sorting, Filtering and top 10 rows
task1_SortTop10 = '''
SELECT *
FROM citibike 
WHERE tripduration >= (3*3600)
ORDER BY start_station_id, tripduration
LIMIT 10 
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task1_SortTop10)), sep=',').head()
# Out:
#    cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0       20353       NaN                   NaN       0         NaN   20703
# 1       11237       NaN                   NaN       1      1990.0   19794
# 2        7128       NaN                   NaN       1      1970.0   21024
# 3       15707       NaN                   NaN       1      1994.0   19870
# 4       41251       NaN                   NaN       2      1978.0   19539
#
#    end_station_id  start_station_id  tripduration    usertype  \
# 0             372                83         33647    Customer
# 1             137               137         13156  Subscriber
# 2             504               152         15251  Subscriber
# 3             375               161         17307  Subscriber
# 4             527               167         23588  Subscriber
#
#             end_station_name             start_station_name  \
# 0  Franklin Ave & Myrtle Ave  Atlantic Ave & Fort Greene Pl
# 1      E 56 St & Madison Ave          E 56 St & Madison Ave
# 2            1 Ave & E 15 St          Warren St & Church St
# 3    Mercer St & Bleecker St          LaGuardia Pl & W 3 St
# 4            E 33 St & 2 Ave                E 39 St & 3 Ave
#
#    end_station_longitude  end_station_latitude  start_station_longitude  \
# 0             -73.958089             40.694528               -73.976323
# 1             -73.972924             40.761628               -73.972924
# 2             -73.981656             40.732219               -74.009106
# 3             -73.996951             40.726795               -73.998102
# 4             -73.976056             40.744023               -73.976049
#
#    start_station_latitude                stoptime               starttime
# 0               40.683826  2015-02-05 05:12:00+00  2015-02-04 19:52:00+00
# 1               40.761628  2015-02-03 21:55:00+00  2015-02-03 18:16:00+00
# 2               40.714740  2015-02-02 18:39:00+00  2015-02-02 14:25:00+00
# 3               40.729170  2015-02-04 16:55:00+00  2015-02-04 12:06:00+00
# 4               40.748901  2015-02-07 18:27:00+00  2015-02-07 11:54:00+00

# %%
# Sorting, filtering and bottom 10 rows
task1_SortBottom10 = '''
SELECT *
FROM citibike 
WHERE tripduration >= (3*3600)
ORDER BY start_station_id DESC, tripduration DESC
LIMIT 10 
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task1_SortBottom10)), sep=',').head()
# Out:
#    cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0       21860       NaN                   NaN       1        1966   18799
# 1         940       NaN                   NaN       2        1985   15140
# 2        8918       NaN                   NaN       1        1987   16808
# 3       40710       NaN                   NaN       2        1993   14988
# 4        9848       NaN                   NaN       1        1990   21398
#
#    end_station_id  start_station_id  tripduration    usertype  \
# 0             336               519         22236  Subscriber
# 1             489               518         11103  Subscriber
# 2             529               514         26502  Subscriber
# 3             490               512         18559  Subscriber
# 4             494               511         17644  Subscriber
#
#               end_station_name     start_station_name  end_station_longitude  \
# 0  Sullivan St & Washington Sq  Pershing Square North             -73.999061
# 1             10 Ave & W 28 St        E 39 St & 2 Ave             -74.001768
# 2              W 42 St & 8 Ave       12 Ave & W 40 St             -73.990985
# 3              8 Ave & W 33 St        W 29 St & 9 Ave             -73.993934
# 4              W 26 St & 8 Ave     E 14 St & Avenue B             -73.997236
#
#    end_station_latitude  start_station_longitude  start_station_latitude  \
# 0             40.730477               -73.977706               40.751873
# 1             40.750664               -73.973442               40.747804
# 2             40.757570               -74.002777               40.760875
# 3             40.751551               -73.998393               40.750073
# 4             40.747348               -73.977724               40.729387
#
#                  stoptime               starttime
# 0  2015-02-05 12:08:00+00  2015-02-05 05:57:00+00
# 1  2015-02-01 13:45:00+00  2015-02-01 10:40:00+00
# 2  2015-02-03 17:12:00+00  2015-02-03 09:50:00+00
# 3  2015-02-07 15:46:00+00  2015-02-07 10:36:00+00
# 4  2015-02-03 19:43:00+00  2015-02-03 14:49:00+00

# %%
# Get Unique start station IDs
task1_UniqueStart = '''
SELECT DISTINCT start_station_id
FROM citibike
ORDER BY start_station_id
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task1_UniqueStart)), sep=',').head()
# Out:
#    start_station_id  Unnamed: 1
# 0                72         NaN
# 1                79         NaN
# 2                82         NaN
# 3                83         NaN
# 4               116         NaN

# %%
# Get Count, Max, Min and Average trip duration
task1_CMMA = '''
SELECT COUNT(*),MAX(tripduration),MIN(tripduration), AVG(tripduration) 
FROM citibike
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task1_CMMA)), sep=',')
# Out:
#    count    max  min         avg
# 0  46200  43016   60  675.865823

# %% [markdown]
# # TASK 2
# ### Define SQL Functions

# %%
# Select Trips that only start on 2015/02/02
Task2_20150202 = '''
SELECT *
FROM citibike
WHERE CAST(starttime AS Date)  = '2015-02-02'
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(Task2_20150202)), sep=',').head()
# Out:
#    cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0        6442       NaN                   NaN       1      1992.0   20684
# 1        6443       NaN                   NaN       2      1964.0   16094
# 2        6444       NaN                   NaN       1      1974.0   17362
# 3        6445       NaN                   NaN       2      1992.0   15475
# 4        6446       NaN                   NaN       1      1968.0   16272
#
#    end_station_id  start_station_id  tripduration    usertype  \
# 0             489               442           199  Subscriber
# 1             349               326           418  Subscriber
# 2             415               279           276  Subscriber
# 3             237               496           420  Subscriber
# 4             450               477           304  Subscriber
#
#             end_station_name    start_station_name  end_station_longitude  \
# 0           10 Ave & W 28 St       W 27 St & 7 Ave             -74.001768
# 1    Rivington St & Ridge St       E 11 St & 1 Ave             -73.983299
# 2  Pearl St & Hanover Square  Peck Slip & Front St             -74.009260
# 3            E 11 St & 2 Ave       E 16 St & 5 Ave             -73.986724
# 4            W 49 St & 8 Ave       W 41 St & 8 Ave             -73.987882
#
#    end_station_latitude  start_station_longitude  start_station_latitude  \
# 0             40.750664               -73.993915               40.746647
# 1             40.718502               -73.984267               40.729538
# 2             40.704718               -74.001670               40.707873
# 3             40.730473               -73.992390               40.737262
# 4             40.762272               -73.990026               40.756405
#
#                  stoptime               starttime
# 0  2015-02-02 00:05:00+00  2015-02-02 00:02:00+00
# 1  2015-02-02 00:10:00+00  2015-02-02 00:03:00+00
# 2  2015-02-02 00:09:00+00  2015-02-02 00:04:00+00
# 3  2015-02-02 00:13:00+00  2015-02-02 00:06:00+00
# 4  2015-02-02 00:12:00+00  2015-02-02 00:07:00+00

# %%
# Select Average Weekend Trip Duration
Task2_AvgWeekend = '''
SELECT AVG(tripduration)
FROM citibike
WHERE EXTRACT(DOW FROM starttime) IN (0,6)
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(Task2_AvgWeekend)), sep=',').head()
# Out:
#           avg  Unnamed: 1
# 0  662.942181         NaN

# %%
# Select Average Weekday Trip Duration
Task2_AvgWeekday = '''
SELECT AVG(tripduration)
FROM citibike
WHERE EXTRACT(DOW FROM starttime) NOT IN (0,6)
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(Task2_AvgWeekday)), sep=',').head()
# Out:
#           avg  Unnamed: 1
# 0  681.052292         NaN

# %% [markdown]
# # TASK 3

# %%
# List of start locations using Group by
Task3_StartLoc = '''
SELECT start_station_name
FROM citibike
GROUP BY start_station_name
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(Task3_StartLoc)), sep=',').head()
# Out:
#         start_station_name  Unnamed: 1
# 0          8 Ave & W 52 St         NaN
# 1  Bank St & Washington St         NaN
# 2           West Thames St         NaN
# 3          W 56 St & 6 Ave         NaN
# 4  Pearl St & Anchorage Pl         NaN

# %%
# Count of start trips by start locations using Group by
Task3_TripsStartLoc = '''
SELECT start_station_name, COUNT(tripduration)
FROM citibike
GROUP BY start_station_name
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(Task3_TripsStartLoc)), sep=',').head()
# Out:
#         start_station_name  count
# 0          8 Ave & W 52 St    133
# 1  Bank St & Washington St    125
# 2           West Thames St    107
# 3          W 56 St & 6 Ave    164
# 4  Pearl St & Anchorage Pl     54

# %%
# Count of start trips by start locations using Group by within 500 meters of Time Square
Task3_TripsStartLocTS = '''
SELECT start_station_name, COUNT(tripduration)
FROM citibike
WHERE ST_DWithin(CDB_LatLng(start_station_latitude,
                            start_station_longitude
                           ) :: geography,
                 CDB_LatLng(40.7577, -73.9857)  :: geography, 500)
GROUP BY start_station_name
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(Task3_TripsStartLocTS)), sep=',').head()
# Out:
#    start_station_name  count
# 0  Broadway & W 49 St    213
# 1  Broadway & W 41 St    251
# 2     W 45 St & 6 Ave    141
# 3     W 41 St & 8 Ave    507
# 4     W 45 St & 8 Ave    141

# %% [markdown]
# # TASK 4

# %%
# Max Average Trip Duration by start locations within 500 meters of Time Square
Task4_1 = '''
SELECT start_station_name, AVG(tripduration)
FROM citibike
WHERE ST_DWithin(CDB_LatLng(start_station_latitude,
                            start_station_longitude
                           ) :: geography,
                 CDB_LatLng(40.7577, -73.9857)  :: geography, 500) 
      AND EXTRACT(DOW FROM starttime) NOT IN (0,6)
GROUP BY start_station_name
ORDER BY AVG(tripduration) DESC
LIMIT 1
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(Task4_1)), sep=',')
# Out:
#   start_station_name         avg
# 0    W 45 St & 8 Ave  727.876289

# %%
# Lines of Trips within 500 meters of Time Square below 2 hours
Task4_2 = '''
SELECT ST_Makeline(
                   CDB_TransformToWebmercator(
                                              CDB_LatLng(
                                                    start_station_latitude,
                                                    start_station_longitude
                                                        )
                                             ),
                   CDB_TransformToWebmercator(
                                              CDB_LatLng(
                                                    end_station_latitude,
                                                    end_station_longitude
                                                        )
                                             )
                   )
                   as the_geom_webmercator,
                   MIN(cartodb_id) as cartodb_id,
                   COUNT(cartodb_id) as number_trips
FROM citibike
WHERE ST_DWithin(CDB_LatLng(start_station_latitude,
                            start_station_longitude
                           ) :: geography,
                 CDB_LatLng(40.7577, -73.9857)  :: geography, 500) 
      AND tripduration <= (2*3600)
GROUP BY start_station_id, start_station_latitude, start_station_longitude,
                 end_station_id, end_station_latitude, end_station_longitude
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(Task4_2)), sep=',').head()
# Out:
#                                 the_geom_webmercator  cartodb_id  number_trips
# 0  0102000020110F00000200000020D6742CE16A5FC112F4...       18466             2
# 1  0102000020110F000002000000F55695027D6B5FC186E5...        2226             2
# 2  0102000020110F00000200000004AF971C1D6B5FC17A48...       15621             2
# 3  0102000020110F0000020000009BB87D02B76A5FC146C1...       34734             1
# 4  0102000020110F000002000000F22A632FBE6A5FC1363A...       37006             1

# %% [markdown]
# # extra credit: make the function python 2 and 3 compatible so that it works on the  PUI2016_Python3 kernel
